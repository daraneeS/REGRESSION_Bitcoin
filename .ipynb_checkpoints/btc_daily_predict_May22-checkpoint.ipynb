# %% [markdown]
# # REGRESSION: Bitcoin Price Forecast
#
# ***

# %% [markdown]
# ## INTRODUCTION

# %% [markdown]
# This project used data from <b style="color:#4361ee">Kraken API</b> and initially applid one machine learning model, <b style="color:#4361ee">Support Vector Machine</b>, to forcast the future price of <b style="color:#4361ee">Bitcoin.</b>

# %%
import numpy as np
import pandas as pd
import json
import datetime
import time
import requests

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.rcParams["font.size"]=14
matplotlib.rcParams["figure.figsize"]= (18,8)
matplotlib.rcParams["figure.facecolor"]="#00000000"

import seaborn as sns
sns.set_style("darkgrid")
import plotly.express as px

# %% [markdown]
# ## DATA COLLECTION

# %% [markdown]
# Kraken gives historical cryptocurrency data. However, the current historical data available is March 31, 2022.
# Therefore, additional data need to be pulled from the API market data endpoint.

# %% [markdown]
# ### 1. Kraken Historical OHLCVT
#
# * https://support.kraken.com/hc/en-us/articles/360047124832-Downloadable-historical-OHLCVT-Open-High-Low-Close-Volume-Trades-data
#
# * The data given is in one minute timeframe, so we will use the 1440 (daily timeframe)
# * The date is in Unix timestamp, so need to be converted to regular date time

# %%
# The columns from the csv file
xbt_cols = ["date","open", "high", "low", "close", "volume", "trades"]

# %%
xbt_raw = pd.read_csv("data/XBTUSD_1440.csv", names=xbt_cols)

# %%
xbt_raw.head(3)
# Out:
#          date    open    high     low   close  volume  trades
# 0  1381017600  122.00  122.00  122.00  122.00  0.1000       1
# 1  1381104000  123.61  123.61  123.61  123.61  0.1000       1
# 2  1381190400  123.91  124.19  123.90  124.18  3.9916       4

# %%
xbt_raw.tail(3)
# Out:
#             date     open     high      low    close       volume  trades
# 3084  1648512000  47138.3  48123.0  46912.5  47440.2  1877.204974   27843
# 3085  1648598400  47440.3  47707.9  46570.6  47059.3  1737.317757   25601
# 3086  1648684800  47079.2  47598.0  45250.0  45524.3  2320.052344   30068

# %%
# Convert Unix timestamp
xbt_raw["date"] = pd.to_datetime(xbt_raw["date"],unit='s')

# %%
xbt_raw.head(3)
# Out:
#         date    open    high     low   close  volume  trades
# 0 2013-10-06  122.00  122.00  122.00  122.00  0.1000       1
# 1 2013-10-07  123.61  123.61  123.61  123.61  0.1000       1
# 2 2013-10-08  123.91  124.19  123.90  124.18  3.9916       4

# %%
xbt_raw.tail(3)
# Out:
#            date     open     high      low    close       volume  trades
# 3084 2022-03-29  47138.3  48123.0  46912.5  47440.2  1877.204974   27843
# 3085 2022-03-30  47440.3  47707.9  46570.6  47059.3  1737.317757   25601
# 3086 2022-03-31  47079.2  47598.0  45250.0  45524.3  2320.052344   30068

# %%
xbt_raw.to_csv("data/xbt_raw.csv")

# %% [markdown]
# ### 2. Kraken API Market data OHLC endpoint
# * Using OHLC endpoint for 2022 data
# * https://docs.kraken.com/rest/#operation/getTickerInformation
# * Unix timestamp converter https://www.epochconverter.com/

# %%
# The columns from OHLC API (different from historical data)

kraken_ohlc_cols = ["date","open", "high", "low", "close", "vwap","volume", "trades"]

# %% [markdown]
# * Without specifying "since" parameter, the response will give the current day data and only 720 data available

# %%
resp = requests.get('https://api.kraken.com/0/public/OHLC?pair=XBTUSD&interval=1440&since=unix_now').json()

# %%
xbt_apr22_df = pd.DataFrame(resp["result"]['XXBTZUSD'])

# %%
xbt_apr22_df.columns = kraken_ohlc_cols
xbt_apr22_df.head(3)
# Out:
#          date    open    high     low   close    vwap         volume  trades
# 0  1591228800  9670.0  9884.7  9465.0  9791.4  9709.4  6818.32814269   18652
# 1  1591315200  9792.1  9855.0  9537.9  9617.7  9719.6  5121.00668816   15855
# 2  1591401600  9617.6  9731.2  9527.4  9672.0  9635.6  2681.15313308   10113

# %%
xbt_apr22_df["date"] = pd.to_datetime(xbt_apr22_df["date"],unit='s')
xbt_apr22_df.head(3)
# Out:
#         date    open    high     low   close    vwap         volume  trades
# 0 2020-06-04  9670.0  9884.7  9465.0  9791.4  9709.4  6818.32814269   18652
# 1 2020-06-05  9792.1  9855.0  9537.9  9617.7  9719.6  5121.00668816   15855
# 2 2020-06-06  9617.6  9731.2  9527.4  9672.0  9635.6  2681.15313308   10113

# %%
xbt_apr22_df.tail(3)
# Out:
#           date     open     high      low    close     vwap         volume  \
# 717 2022-05-22  29394.4  30500.0  29225.7  30268.0  29975.5  1862.49212439
# 718 2022-05-23  30264.4  30630.7  28829.5  29070.0  29874.3  3028.92781142
# 719 2022-05-24  29070.0  29631.9  28635.3  29340.0  29168.7  2124.84421360
#
#      trades
# 717   15723
# 718   22623
# 719   14554

# %% [markdown]
# ### Appending data from OHLC API to dataframe from historical data

# %% [markdown]
# <b>Drop vwap column since there's no vwap column in the historical data</b>

# %%
# Drop vwap column since there's no vwap column in the historical data

xbt_apr22_df.drop("vwap", axis=1, inplace=True)
xbt_apr22_df.head(3)
# Out:
#         date    open    high     low   close         volume  trades
# 0 2020-06-04  9670.0  9884.7  9465.0  9791.4  6818.32814269   18652
# 1 2020-06-05  9792.1  9855.0  9537.9  9617.7  5121.00668816   15855
# 2 2020-06-06  9617.6  9731.2  9527.4  9672.0  2681.15313308   10113

# %% [markdown]
# <b> Select the data after March 31,2022 </b>

# %%
xbt_apr22 = xbt_apr22_df[xbt_apr22_df["date"] > "2022-03-31"]
xbt_apr22
# Out:
#           date     open     high      low    close          volume  trades
# 666 2022-04-01  45523.5  46710.9  44257.6  46312.0   4181.29834325   36546
# 667 2022-04-02  46312.0  47200.0  45666.1  45828.6   1420.18952030   22824
# 668 2022-04-03  45828.6  47444.9  45566.0  46423.4   1245.97997739   20620
# 669 2022-04-04  46424.2  46888.0  45153.0  46617.1   1910.97459708   23949
# 670 2022-04-05  46617.1  47188.4  45377.0  45479.2   1882.88025051   22655
# 671 2022-04-06  45498.3  45534.3  43123.7  43179.4   4589.10698672   36043
# 672 2022-04-07  43179.5  43920.8  42750.0  43469.8   1565.17601256   22151
# 673 2022-04-08  43469.8  43968.7  42126.0  42282.6   2238.74341635   26125
# 674 2022-04-09  42282.6  42805.1  42111.0  42764.0    621.74608186   13343
# 675 2022-04-10  42781.7  43416.4  41805.4  42160.0   1121.27095145   15302
# 676 2022-04-11  42164.9  42411.0  39240.0  39534.6   3303.89909080   31753
# 677 2022-04-12  39530.5  40683.4  39269.4  40078.7   2170.32737648   24269
# 678 2022-04-13  40078.7  41548.4  39598.0  41150.0   2414.27057701   24018
# 679 2022-04-14  41150.0  41480.0  39600.0  39954.9   1895.26356688   20685
# 680 2022-04-15  39953.7  40890.3  39800.0  40569.9   1177.17180956   16024
# 681 2022-04-16  40570.0  40708.8  40011.9  40381.0    589.46381724   12703
# 682 2022-04-17  40381.1  40652.8  39556.0  39681.2    982.00936665   15246
# 683 2022-04-18  39680.5  41067.3  38570.0  40811.3   2626.83895679   27165
# 684 2022-04-19  40811.3  41825.8  40600.0  41506.2   1433.48126987   20860
# 685 2022-04-20  41506.2  42235.7  40900.8  41369.9   1847.47895334   24598
# 686 2022-04-21  41370.0  42950.0  39800.6  40484.1   3322.74818736   32797
# 687 2022-04-22  40479.1  40791.3  39139.0  39715.9   2214.67239669   27687
# 688 2022-04-23  39713.5  39958.4  39310.0  39435.6    813.96002029   16509
# 689 2022-04-24  39439.3  39911.0  39015.8  39467.9   1138.59124375   14218
# 690 2022-04-25  39456.7  40614.5  38200.5  40438.5   4131.19598091   32601
# 691 2022-04-26  40438.4  40776.9  37672.0  38121.7   4450.89465927   34470
# 692 2022-04-27  38121.7  39446.8  37909.4  39249.9   3384.95426898   25789
# 693 2022-04-28  39249.9  40349.8  38884.4  39752.8   3135.47777394   27554
# 694 2022-04-29  39749.8  39920.7  38131.8  38599.5   2451.16979000   26059
# 695 2022-04-30  38597.5  38777.4  37608.7  37660.8   1090.27309591   18103
# 696 2022-05-01  37660.7  38660.0  37399.4  38474.1   1633.98318627   21895
# 697 2022-05-02  38470.8  39169.4  38011.0  38499.9   2642.20787837   25583
# 698 2022-05-03  38499.9  38645.1  37507.9  37727.9   1875.03601922   20456
# 699 2022-05-04  37727.9  40029.8  37674.8  39682.8   3072.74719791   28648
# 700 2022-05-05  39677.6  39832.0  35407.0  36542.6   5103.89656374   38621
# 701 2022-05-06  36540.4  36647.0  35280.0  36017.4   2897.56279581   29119
# 702 2022-05-07  36017.4  36105.9  34755.0  35463.0   1293.31044199   21149
# 703 2022-05-08  35463.1  35495.0  33700.0  34024.2   3717.25105101   29643
# 704 2022-05-09  34028.3  34214.1  30050.0  30075.5  11297.51359129   59841
# 705 2022-05-10  30052.6  32648.6  29755.0  30999.9  10419.54135811   59593
# 706 2022-05-11  30999.9  32132.0  27700.0  28994.1  14865.74600975   78783
# 707 2022-05-12  28998.2  30075.9  25332.8  28943.4  12160.55241802   73670
# 708 2022-05-13  28943.5  30966.0  28684.5  29222.6   4289.72165684   36428
# 709 2022-05-14  29232.8  30264.0  28600.5  30048.2   2749.78304312   30315
# 710 2022-05-15  30051.7  31390.0  29452.6  31296.9   1579.87172232   24094
# 711 2022-05-16  31294.5  31294.5  29060.0  29826.1   3703.17450500   28913
# 712 2022-05-17  29826.1  30742.0  29403.0  30408.3   2810.86074049   23704
# 713 2022-05-18  30408.4  30653.1  28589.1  28664.3   4177.51533145   26075
# 714 2022-05-19  28657.6  30503.7  28649.2  30280.7   3722.85334692   25266
# 715 2022-05-20  30283.7  30721.2  28700.1  29167.5   3717.55661319   24027
# 716 2022-05-21  29161.6  29606.3  28927.3  29403.5   1030.06024928   13342
# 717 2022-05-22  29394.4  30500.0  29225.7  30268.0   1862.49212439   15723
# 718 2022-05-23  30264.4  30630.7  28829.5  29070.0   3028.92781142   22623
# 719 2022-05-24  29070.0  29631.9  28635.3  29340.0   2124.84421360   14554

# %% [markdown]
# <b> Combine the two dataframes</b>

# %%
btc_df_raw = pd.concat([xbt_raw, xbt_apr22],ignore_index=True)

# %%
btc_df_raw.head(3)
# Out:
#         date    open    high     low   close  volume  trades
# 0 2013-10-06   122.0   122.0   122.0   122.0     0.1       1
# 1 2013-10-07  123.61  123.61  123.61  123.61     0.1       1
# 2 2013-10-08  123.91  124.19   123.9  124.18  3.9916       4

# %%
btc_df_raw.tail(3)
# Out:
#            date     open     high      low    close         volume  trades
# 3138 2022-05-22  29394.4  30500.0  29225.7  30268.0  1862.49212439   15723
# 3139 2022-05-23  30264.4  30630.7  28829.5  29070.0  3028.92781142   22623
# 3140 2022-05-24  29070.0  29631.9  28635.3  29340.0  2124.84421360   14554

# %%
btc_df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3141 entries, 0 to 3140
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    3141 non-null   datetime64[ns]
#  1   open    3141 non-null   object
#  2   high    3141 non-null   object
#  3   low     3141 non-null   object
#  4   close   3141 non-null   object
#  5   volume  3141 non-null   object
#  6   trades  3141 non-null   int64
# dtypes: datetime64[ns](1), int64(1), object(5)
# memory usage: 171.9+ KB

# %%
btc_df_raw = btc_df_raw.astype({"open":"float64", 
                               "high":"float64", 
                                "low":"float64", 
                               "close":"float64", 
                             "volume":"float64"})

# %%
btc_df_raw.to_csv("data/btc_df_raw.csv") # save data for later use

# %% [markdown]
# ## DATA PREPROCESSING

# %% [markdown]
# ### Create more features

# %%
btc_df = pd.read_csv("data/btc_df_raw.csv", index_col=0)

# %%
btc_df.head(2)
# Out:
#          date    open    high     low   close  volume  trades
# 0  2013-10-06  122.00  122.00  122.00  122.00     0.1       1
# 1  2013-10-07  123.61  123.61  123.61  123.61     0.1       1

# %%
btc_df.tail(2)
# Out:
#             date     open     high      low    close       volume  trades
# 3139  2022-05-23  30264.4  30630.7  28829.5  29070.0  3028.927811   22623
# 3140  2022-05-24  29070.0  29631.9  28635.3  29340.0  2124.844214   14554

# %%
btc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3141 entries, 0 to 3140
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    3141 non-null   object
#  1   open    3141 non-null   float64
#  2   high    3141 non-null   float64
#  3   low     3141 non-null   float64
#  4   close   3141 non-null   float64
#  5   volume  3141 non-null   float64
#  6   trades  3141 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 196.3+ KB

# %% [markdown]
# #### Split date column to year, month, day

# %%
def date_split(df):
    df["date"] = pd.to_datetime(df["date"])
    df["year"] = df["date"].dt.year
    df["month"] = df["date"].dt.month
    df["day"] = df["date"].dt.day
    return(df)

# %%
btc_df = date_split(btc_df)

# %%
btc_df = btc_df[["date","year", "month", "day", "open", "high", "low", "close", "volume", "trades"]]

# %%
btc_df.head(3)
# Out:
#         date  year  month  day    open    high     low   close  volume  trades
# 0 2013-10-06  2013     10    6  122.00  122.00  122.00  122.00  0.1000       1
# 1 2013-10-07  2013     10    7  123.61  123.61  123.61  123.61  0.1000       1
# 2 2013-10-08  2013     10    8  123.91  124.19  123.90  124.18  3.9916       4

# %%
btc_df = btc_df.set_index("date")

# %%
btc_df.head(3)
# Out:
#             year  month  day    open    high     low   close  volume  trades
# date
# 2013-10-06  2013     10    6  122.00  122.00  122.00  122.00  0.1000       1
# 2013-10-07  2013     10    7  123.61  123.61  123.61  123.61  0.1000       1
# 2013-10-08  2013     10    8  123.91  124.19  123.90  124.18  3.9916       4

# %% [markdown]
# #### Adding Yesterday prices, volume, trades

# %%
def yesterday_data(df):
    df["open_yesterday"] = df["open"].shift(1)
    df["high_yesterday"] = df["high"].shift(1)
    df["low_yesterday"] = df["low"].shift(1)
    df["close_yesterday"] = df["close"].shift(1)
    df["volume_yesterday"] = df["volume"].shift(1)
    df["trades_yesterday"] = df["trades"].shift(1)
    return(df)

# %%
btc_df = yesterday_data(btc_df)

# %% [markdown]
# #### Adding % change of yesterday and the day before yesterday
#
# price_1D_change = (today_price - yesterday_price)/yesterday_price

# %%
def change_1D(df):
    df["open_1D_change"] = btc_df["open"].pct_change().shift(1)
    df["high_1D_change"] = btc_df["high"].pct_change().shift(1)
    df["low_1D_change"]  = df["low"].pct_change().shift(1)
    df["close_1D_change"] = df["close"].pct_change().shift(1)
    df["volume_1D_change"] = df["volume"].pct_change().shift(1)
    df["trades_1D_change"] = df["trades"].pct_change().shift(1)
    return(df)

# %%
btc_df = change_1D(btc_df)

# %% [markdown]
# #### Average 7 days

# %% [markdown]
# - rolling will include the current row to calculate
# - so if we are at row#8 (index=7), we can calculate mean of the first 7 rows
# - then shiff the value to row#8

# %%
def moving_ave_7(df):
    df["open_average_7D"] = df["open"].rolling(7).mean().shift(1)
    df["high_average_7D"] = df["high"].rolling(7).mean().shift(1)
    df["low_average_7D"] = df["low"].rolling(7).mean().shift(1)
    df["close_average_7D"] = df["close"].rolling(7).mean().shift(1)
    df["volume_average_7D"] = df["volume"].rolling(7).mean().shift(1)
    df["trades_average_7D"] = df["trades"].rolling(7).mean().shift(1)
    
    return(df)

# %%
btc_df = moving_ave_7(btc_df)

# %% [markdown]
# #### % change 7 days

# %%
def change_pct_7D(df):
    df["open_%change_7D"] = df["open_1D_change"].rolling(7).mean().shift(1)
    df["high_%change_7D"] = df["high_1D_change"].rolling(7).mean().shift(1)
    df["low_%change_7D"] = df["low_1D_change"].rolling(7).mean().shift(1)
    df["close_%change_7D"] = df["close_1D_change"].rolling(7).mean().shift(1)
    df["volume_%change_7D"] = df["volume_1D_change"].rolling(7).mean().shift(1)
    df["trades_%change_7D"] = df["trades_1D_change"].rolling(7).mean().shift(1)
    
    return(df)

# %%
btc_df = change_pct_7D(btc_df)

# %% [markdown]
# #### Simple Moving Average 9, 20, 50
# - Will only use ["close"] here

# %%
def moving_avgs_pop(df):
    df["moving_average_9"] = df["close"].rolling(9).mean().shift(1)
    df["moving_average_20"] = df["close"].rolling(20).mean().shift(1)
    df["moving_average_50"] = df["close"].rolling(50).mean().shift(1)
    
    return(df)

# %%
btc_df = moving_avgs_pop(btc_df)

# %% [markdown]
# <b> Set the display to see all columns </b>

# %%
pd.set_option("display.max_columns", len(btc_df.columns))

# %%
btc_df.head(3)
# Out:
#             year  month  day    open    high     low   close  volume  trades  \
# date
# 2013-10-06  2013     10    6  122.00  122.00  122.00  122.00  0.1000       1
# 2013-10-07  2013     10    7  123.61  123.61  123.61  123.61  0.1000       1
# 2013-10-08  2013     10    8  123.91  124.19  123.90  124.18  3.9916       4
#
#             open_yesterday  high_yesterday  low_yesterday  close_yesterday  \
# date
# 2013-10-06             NaN             NaN            NaN              NaN
# 2013-10-07          122.00          122.00         122.00           122.00
# 2013-10-08          123.61          123.61         123.61           123.61
#
#             volume_yesterday  trades_yesterday  open_1D_change  \
# date
# 2013-10-06               NaN               NaN             NaN
# 2013-10-07               0.1               1.0             NaN
# 2013-10-08               0.1               1.0        0.013197
#
#             high_1D_change  low_1D_change  close_1D_change  volume_1D_change  \
# date
# 2013-10-06             NaN            NaN              NaN               NaN
# 2013-10-07             NaN            NaN              NaN               NaN
# 2013-10-08        0.013197       0.013197         0.013197               0.0
#
#             trades_1D_change  open_average_7D  high_average_7D  \
# date
# 2013-10-06               NaN              NaN              NaN
# 2013-10-07               NaN              NaN              NaN
# 2013-10-08               0.0              NaN              NaN
#
#             low_average_7D  close_average_7D  volume_average_7D  \
# date
# 2013-10-06             NaN               NaN                NaN
# 2013-10-07             NaN               NaN                NaN
# 2013-10-08             NaN               NaN                NaN
#
#             trades_average_7D  open_%change_7D  high_%change_7D  \
# date
# 2013-10-06                NaN              NaN              NaN
# 2013-10-07                NaN              NaN              NaN
# 2013-10-08                NaN              NaN              NaN
#
#             low_%change_7D  close_%change_7D  volume_%change_7D  \
# date
# 2013-10-06             NaN               NaN                NaN
# 2013-10-07             NaN               NaN                NaN
# 2013-10-08             NaN               NaN                NaN
#
#             trades_%change_7D  moving_average_9  moving_average_20  \
# date
# 2013-10-06                NaN               NaN                NaN
# 2013-10-07                NaN               NaN                NaN
# 2013-10-08                NaN               NaN                NaN
#
#             moving_average_50
# date
# 2013-10-06                NaN
# 2013-10-07                NaN
# 2013-10-08                NaN

# %%
btc_df.tail(3)
# Out:
#             year  month  day     open     high      low    close       volume  \
# date
# 2022-05-22  2022      5   22  29394.4  30500.0  29225.7  30268.0  1862.492124
# 2022-05-23  2022      5   23  30264.4  30630.7  28829.5  29070.0  3028.927811
# 2022-05-24  2022      5   24  29070.0  29631.9  28635.3  29340.0  2124.844214
#
#             trades  open_yesterday  high_yesterday  low_yesterday  \
# date
# 2022-05-22   15723         29161.6         29606.3        28927.3
# 2022-05-23   22623         29394.4         30500.0        29225.7
# 2022-05-24   14554         30264.4         30630.7        28829.5
#
#             close_yesterday  volume_yesterday  trades_yesterday  \
# date
# 2022-05-22          29403.5       1030.060249           13342.0
# 2022-05-23          30268.0       1862.492124           15723.0
# 2022-05-24          29070.0       3028.927811           22623.0
#
#             open_1D_change  high_1D_change  low_1D_change  close_1D_change  \
# date
# 2022-05-22       -0.037053       -0.036291       0.007916         0.008091
# 2022-05-23        0.007983        0.030186       0.010316         0.029401
# 2022-05-24        0.029597        0.004285      -0.013557        -0.039580
#
#             volume_1D_change  trades_1D_change  open_average_7D  \
# date
# 2022-05-22         -0.722920         -0.444708     29954.800000
# 2022-05-23          0.808139          0.178459     29860.900000
# 2022-05-24          0.626277          0.438848     29713.742857
#
#             high_average_7D  low_average_7D  close_average_7D  \
# date
# 2022-05-22     30701.542857    28968.757143      29863.900000
# 2022-05-23     30574.400000    28936.342857      29716.914286
# 2022-05-24     30479.571429    28903.414286      29608.900000
#
#             volume_average_7D  trades_average_7D  open_%change_7D  \
# date
# 2022-05-22        2963.127501       23631.571429         0.007304
# 2022-05-23        3003.501844       22435.714286         0.000583
# 2022-05-24        2907.180888       21537.142857        -0.002278
#
#             high_%change_7D  low_%change_7D  close_%change_7D  \
# date
# 2022-05-22        -0.000971        0.000219          0.000658
# 2022-05-23        -0.002917        0.001769         -0.002222
# 2022-05-24        -0.003920       -0.001014         -0.003958
#
#             volume_%change_7D  trades_%change_7D  moving_average_9  \
# date
# 2022-05-22           0.099217          -0.047602      29813.122222
# 2022-05-23           0.047226          -0.087159      29929.277778
# 2022-05-24           0.223454          -0.032349      29820.588889
#
#             moving_average_20  moving_average_50
# date
# 2022-05-22          32264.440          37598.628
# 2022-05-23          31852.845          37287.416
# 2022-05-24          31419.950          36940.348

# %% [markdown]
# #### Drop NaN

# %%
len(btc_df)
# Out:
# 3141

# %%
btc_df = btc_df.dropna()

# %%
len(btc_df)
# Out:
# 3091

# %%
btc_df.head(3)
# Out:
#             year  month  day        open        high         low       close  \
# date
# 2013-11-27  2013     11   27   893.90000  1081.09181   890.00000   994.95000
# 2013-11-28  2013     11   28   994.95000  1088.41486   935.08060  1000.32893
# 2013-11-29  2013     11   29  1012.39302  1198.80090  1012.39302  1165.42500
#
#                volume  trades  open_yesterday  high_yesterday  low_yesterday  \
# date
# 2013-11-27  46.413145     782       801.59886       900.00000      768.58034
# 2013-11-28  33.030364     443       893.90000      1081.09181      890.00000
# 2013-11-29  34.827289     562       994.95000      1088.41486      935.08060
#
#             close_yesterday  volume_yesterday  trades_yesterday  \
# date
# 2013-11-27        893.87025         13.846622             351.0
# 2013-11-28        994.95000         46.413145             782.0
# 2013-11-29       1000.32893         33.030364             443.0
#
#             open_1D_change  high_1D_change  low_1D_change  close_1D_change  \
# date
# 2013-11-27       -0.004225        0.099752       0.052850         0.115109
# 2013-11-28        0.115146        0.201213       0.157979         0.113081
# 2013-11-29        0.113044        0.006774       0.050652         0.005406
#
#             volume_1D_change  trades_1D_change  open_average_7D  \
# date
# 2013-11-27          0.275832          0.290441       727.991971
# 2013-11-28          2.351947          1.227920       772.591843
# 2013-11-29         -0.288340         -0.433504       829.013271
#
#             high_average_7D  low_average_7D  close_average_7D  \
# date
# 2013-11-27       804.052834      671.933386        770.428236
# 2013-11-28       867.501920      734.790529        828.019664
# 2013-11-29       920.132614      785.071979        875.200880
#
#             volume_average_7D  trades_average_7D  open_%change_7D  \
# date
# 2013-11-27          32.574112         296.428571         0.084394
# 2013-11-28          31.094427         358.142857         0.025183
# 2013-11-29          25.518049         364.142857         0.065775
#
#             high_%change_7D  low_%change_7D  close_%change_7D  \
# date
# 2013-11-27         0.030572        0.064017          0.025034
# 2013-11-28         0.024414        0.075126          0.064433
# 2013-11-29         0.082275        0.107730          0.079544
#
#             volume_%change_7D  trades_%change_7D  moving_average_9  \
# date
# 2013-11-27           0.056438           0.146473        742.279831
# 2013-11-28           0.047896           0.077178        775.052053
# 2013-11-29           0.378996           0.299667        820.919620
#
#             moving_average_20  moving_average_50
# date
# 2013-11-27         540.766110         319.194435
# 2013-11-28         576.032168         336.653435
# 2013-11-29         609.516222         354.187814

# %%
btc_df.tail(3)
# Out:
#             year  month  day     open     high      low    close       volume  \
# date
# 2022-05-22  2022      5   22  29394.4  30500.0  29225.7  30268.0  1862.492124
# 2022-05-23  2022      5   23  30264.4  30630.7  28829.5  29070.0  3028.927811
# 2022-05-24  2022      5   24  29070.0  29631.9  28635.3  29340.0  2124.844214
#
#             trades  open_yesterday  high_yesterday  low_yesterday  \
# date
# 2022-05-22   15723         29161.6         29606.3        28927.3
# 2022-05-23   22623         29394.4         30500.0        29225.7
# 2022-05-24   14554         30264.4         30630.7        28829.5
#
#             close_yesterday  volume_yesterday  trades_yesterday  \
# date
# 2022-05-22          29403.5       1030.060249           13342.0
# 2022-05-23          30268.0       1862.492124           15723.0
# 2022-05-24          29070.0       3028.927811           22623.0
#
#             open_1D_change  high_1D_change  low_1D_change  close_1D_change  \
# date
# 2022-05-22       -0.037053       -0.036291       0.007916         0.008091
# 2022-05-23        0.007983        0.030186       0.010316         0.029401
# 2022-05-24        0.029597        0.004285      -0.013557        -0.039580
#
#             volume_1D_change  trades_1D_change  open_average_7D  \
# date
# 2022-05-22         -0.722920         -0.444708     29954.800000
# 2022-05-23          0.808139          0.178459     29860.900000
# 2022-05-24          0.626277          0.438848     29713.742857
#
#             high_average_7D  low_average_7D  close_average_7D  \
# date
# 2022-05-22     30701.542857    28968.757143      29863.900000
# 2022-05-23     30574.400000    28936.342857      29716.914286
# 2022-05-24     30479.571429    28903.414286      29608.900000
#
#             volume_average_7D  trades_average_7D  open_%change_7D  \
# date
# 2022-05-22        2963.127501       23631.571429         0.007304
# 2022-05-23        3003.501844       22435.714286         0.000583
# 2022-05-24        2907.180888       21537.142857        -0.002278
#
#             high_%change_7D  low_%change_7D  close_%change_7D  \
# date
# 2022-05-22        -0.000971        0.000219          0.000658
# 2022-05-23        -0.002917        0.001769         -0.002222
# 2022-05-24        -0.003920       -0.001014         -0.003958
#
#             volume_%change_7D  trades_%change_7D  moving_average_9  \
# date
# 2022-05-22           0.099217          -0.047602      29813.122222
# 2022-05-23           0.047226          -0.087159      29929.277778
# 2022-05-24           0.223454          -0.032349      29820.588889
#
#             moving_average_20  moving_average_50
# date
# 2022-05-22          32264.440          37598.628
# 2022-05-23          31852.845          37287.416
# 2022-05-24          31419.950          36940.348

# %% [markdown]
# #### Save dataframe for later use for Machine Learaning model

# %%
btc_df.to_csv("data/btc_df.csv")

# %% [markdown]
# # VISUALIZATION

# %%
btc_df.head(3)
# Out:
#             year  month  day        open        high         low       close  \
# date
# 2013-11-27  2013     11   27   893.90000  1081.09181   890.00000   994.95000
# 2013-11-28  2013     11   28   994.95000  1088.41486   935.08060  1000.32893
# 2013-11-29  2013     11   29  1012.39302  1198.80090  1012.39302  1165.42500
#
#                volume  trades  open_yesterday  high_yesterday  low_yesterday  \
# date
# 2013-11-27  46.413145     782       801.59886       900.00000      768.58034
# 2013-11-28  33.030364     443       893.90000      1081.09181      890.00000
# 2013-11-29  34.827289     562       994.95000      1088.41486      935.08060
#
#             close_yesterday  volume_yesterday  trades_yesterday  \
# date
# 2013-11-27        893.87025         13.846622             351.0
# 2013-11-28        994.95000         46.413145             782.0
# 2013-11-29       1000.32893         33.030364             443.0
#
#             open_1D_change  high_1D_change  low_1D_change  close_1D_change  \
# date
# 2013-11-27       -0.004225        0.099752       0.052850         0.115109
# 2013-11-28        0.115146        0.201213       0.157979         0.113081
# 2013-11-29        0.113044        0.006774       0.050652         0.005406
#
#             volume_1D_change  trades_1D_change  open_average_7D  \
# date
# 2013-11-27          0.275832          0.290441       727.991971
# 2013-11-28          2.351947          1.227920       772.591843
# 2013-11-29         -0.288340         -0.433504       829.013271
#
#             high_average_7D  low_average_7D  close_average_7D  \
# date
# 2013-11-27       804.052834      671.933386        770.428236
# 2013-11-28       867.501920      734.790529        828.019664
# 2013-11-29       920.132614      785.071979        875.200880
#
#             volume_average_7D  trades_average_7D  open_%change_7D  \
# date
# 2013-11-27          32.574112         296.428571         0.084394
# 2013-11-28          31.094427         358.142857         0.025183
# 2013-11-29          25.518049         364.142857         0.065775
#
#             high_%change_7D  low_%change_7D  close_%change_7D  \
# date
# 2013-11-27         0.030572        0.064017          0.025034
# 2013-11-28         0.024414        0.075126          0.064433
# 2013-11-29         0.082275        0.107730          0.079544
#
#             volume_%change_7D  trades_%change_7D  moving_average_9  \
# date
# 2013-11-27           0.056438           0.146473        742.279831
# 2013-11-28           0.047896           0.077178        775.052053
# 2013-11-29           0.378996           0.299667        820.919620
#
#             moving_average_20  moving_average_50
# date
# 2013-11-27         540.766110         319.194435
# 2013-11-28         576.032168         336.653435
# 2013-11-29         609.516222         354.187814

# %%
btc_df.tail(3)
# Out:
#             year  month  day     open     high      low    close       volume  \
# date
# 2022-05-22  2022      5   22  29394.4  30500.0  29225.7  30268.0  1862.492124
# 2022-05-23  2022      5   23  30264.4  30630.7  28829.5  29070.0  3028.927811
# 2022-05-24  2022      5   24  29070.0  29631.9  28635.3  29340.0  2124.844214
#
#             trades  open_yesterday  high_yesterday  low_yesterday  \
# date
# 2022-05-22   15723         29161.6         29606.3        28927.3
# 2022-05-23   22623         29394.4         30500.0        29225.7
# 2022-05-24   14554         30264.4         30630.7        28829.5
#
#             close_yesterday  volume_yesterday  trades_yesterday  \
# date
# 2022-05-22          29403.5       1030.060249           13342.0
# 2022-05-23          30268.0       1862.492124           15723.0
# 2022-05-24          29070.0       3028.927811           22623.0
#
#             open_1D_change  high_1D_change  low_1D_change  close_1D_change  \
# date
# 2022-05-22       -0.037053       -0.036291       0.007916         0.008091
# 2022-05-23        0.007983        0.030186       0.010316         0.029401
# 2022-05-24        0.029597        0.004285      -0.013557        -0.039580
#
#             volume_1D_change  trades_1D_change  open_average_7D  \
# date
# 2022-05-22         -0.722920         -0.444708     29954.800000
# 2022-05-23          0.808139          0.178459     29860.900000
# 2022-05-24          0.626277          0.438848     29713.742857
#
#             high_average_7D  low_average_7D  close_average_7D  \
# date
# 2022-05-22     30701.542857    28968.757143      29863.900000
# 2022-05-23     30574.400000    28936.342857      29716.914286
# 2022-05-24     30479.571429    28903.414286      29608.900000
#
#             volume_average_7D  trades_average_7D  open_%change_7D  \
# date
# 2022-05-22        2963.127501       23631.571429         0.007304
# 2022-05-23        3003.501844       22435.714286         0.000583
# 2022-05-24        2907.180888       21537.142857        -0.002278
#
#             high_%change_7D  low_%change_7D  close_%change_7D  \
# date
# 2022-05-22        -0.000971        0.000219          0.000658
# 2022-05-23        -0.002917        0.001769         -0.002222
# 2022-05-24        -0.003920       -0.001014         -0.003958
#
#             volume_%change_7D  trades_%change_7D  moving_average_9  \
# date
# 2022-05-22           0.099217          -0.047602      29813.122222
# 2022-05-23           0.047226          -0.087159      29929.277778
# 2022-05-24           0.223454          -0.032349      29820.588889
#
#             moving_average_20  moving_average_50
# date
# 2022-05-22          32264.440          37598.628
# 2022-05-23          31852.845          37287.416
# 2022-05-24          31419.950          36940.348

# %%
btc_df_viz = btc_df[:-1]  # drop last row because the trading day isn't closed yet

# %%
btc_df_viz.tail(3)
# Out:
#             year  month  day     open     high      low    close       volume  \
# date
# 2022-05-21  2022      5   21  29161.6  29606.3  28927.3  29403.5  1030.060249
# 2022-05-22  2022      5   22  29394.4  30500.0  29225.7  30268.0  1862.492124
# 2022-05-23  2022      5   23  30264.4  30630.7  28829.5  29070.0  3028.927811
#
#             trades  open_yesterday  high_yesterday  low_yesterday  \
# date
# 2022-05-21   13342         30283.7         30721.2        28700.1
# 2022-05-22   15723         29161.6         29606.3        28927.3
# 2022-05-23   22623         29394.4         30500.0        29225.7
#
#             close_yesterday  volume_yesterday  trades_yesterday  \
# date
# 2022-05-21          29167.5       3717.556613           24027.0
# 2022-05-22          29403.5       1030.060249           13342.0
# 2022-05-23          30268.0       1862.492124           15723.0
#
#             open_1D_change  high_1D_change  low_1D_change  close_1D_change  \
# date
# 2022-05-21        0.056742        0.007130       0.001777        -0.036763
# 2022-05-22       -0.037053       -0.036291       0.007916         0.008091
# 2022-05-23        0.007983        0.030186       0.010316         0.029401
#
#             volume_1D_change  trades_1D_change  open_average_7D  \
# date
# 2022-05-21         -0.001423         -0.049038     29964.971429
# 2022-05-22         -0.722920         -0.444708     29954.800000
# 2022-05-23          0.808139          0.178459     29860.900000
#
#             high_average_7D  low_average_7D  close_average_7D  \
# date
# 2022-05-21     30795.500000    28922.071429      29956.000000
# 2022-05-22     30701.542857    28968.757143      29863.900000
# 2022-05-23     30574.400000    28936.342857      29716.914286
#
#             volume_average_7D  trades_average_7D  open_%change_7D  \
# date
# 2022-05-21        3208.802186       26056.285714        -0.001071
# 2022-05-22        2963.127501       23631.571429         0.007304
# 2022-05-23        3003.501844       22435.714286         0.000583
#
#             high_%change_7D  low_%change_7D  close_%change_7D  \
# date
# 2022-05-21         0.002238        0.018867          0.007288
# 2022-05-22        -0.000971        0.000219          0.000658
# 2022-05-23        -0.002917        0.001769         -0.002222
#
#             volume_%change_7D  trades_%change_7D  moving_average_9  \
# date
# 2022-05-21           0.006957          -0.112814      29762.000000
# 2022-05-22           0.099217          -0.047602      29813.122222
# 2022-05-23           0.047226          -0.087159      29929.277778
#
#             moving_average_20  moving_average_50
# date
# 2022-05-21          32717.970          37936.798
# 2022-05-22          32264.440          37598.628
# 2022-05-23          31852.845          37287.416

# %% [markdown]
# <b> Close Price Trend </b>

# %%
btc_df_viz['close'].plot(color="green") 
plt.title("Bitcoin Close Price", fontweight="bold", y=1.025)#fontname="Times New Roman"
plt.show()

# %% [markdown]
# <b> Volume Trend </b>

# %%
btc_df_viz['volume'].plot(color="green")
plt.title("Bitcoin Volume", fontweight="bold", y=1.025)
plt.show()

# %% [markdown]
# <b> Trades Trend </b>

# %%
btc_df_viz['trades'].plot(color="green")
plt.title("Bitcoin Trades", fontweight="bold", y=1.025)
plt.show()

# %% [markdown]
# <b> Box Plot Close Price </b>

# %%
box = sns.boxplot(x=btc_df_viz["year"], y=btc_df_viz["close"], data=btc_df_viz)

box.set_title("BitCoin Close Price",y=1.025, fontdict= {'fontweight':'bold',"fontsize":18})
box.set_xlabel("Year", fontsize=16)
box.set_ylabel(None, fontsize=16)
# Out:
# Text(0, 0.5, '')

# %% [markdown]
# <b> Box Plot Volume </b>

# %%
box1 = sns.boxplot(x=btc_df_viz["year"], y=btc_df_viz["volume"], data=btc_df_viz)

box1.set_title("BitCoin Averge Volume",y=1.025, fontdict= {'fontweight':'bold',"fontsize":18})
box1.set_xlabel("Year", fontsize=16)
box1.set_ylabel(None, fontsize=16)
# Out:
# Text(0, 0.5, '')

# %% [markdown]
# <b> Box Plot Trades </b>

# %%
box2 = sns.boxplot(x=btc_df_viz["year"], y=btc_df_viz["trades"], data=btc_df_viz)

box2.set_title("BitCoin Averge Trades",y=1.025, fontdict= {'fontweight':'bold',"fontsize":18})
box2.set_xlabel("Year", fontsize=16)
box2.set_ylabel(None, fontsize=16)
# Out:
# Text(0, 0.5, '')

# %%
btc_avg = pd.DataFrame(btc_df_viz.groupby(['year'])['open'].mean())
btc_avg["high"] = pd.DataFrame(btc_df_viz.groupby(['year'])['high'].mean())
btc_avg["low"] = pd.DataFrame(btc_df_viz.groupby(['year'])['low'].mean())
btc_avg["close"] = pd.DataFrame(btc_df_viz.groupby(['year'])['close'].mean())
btc_avg["volume"] = pd.DataFrame(btc_df_viz.groupby(['year'])['volume'].mean())
btc_avg["trades"] = pd.DataFrame(btc_df_viz.groupby(['year'])['trades'].mean())
btc_avg
# Out:
#               open          high           low         close       volume  \
# year
# 2013    834.430256    887.545685    763.786884    828.310699    43.388851
# 2014    533.016193    548.639927    515.940908    531.499985    14.195329
# 2015    271.471425    278.831813    265.153542    272.323858    77.278983
# 2016    566.870884    576.048015    557.450315    568.276695  1283.666737
# 2017   3936.776534   4118.183701   3767.023499   3972.502397  5048.121496
# 2018   7552.732329   7783.027671   7258.388493   7523.407671  6301.052699
# 2019   7355.562466   7562.660548   7131.104658   7364.964110  6106.849901
# 2020  11056.251366  11336.646721  10783.763934  11116.068579  6386.292323
# 2021  47378.112329  48812.425753  45668.609041  47426.086301  5254.154224
# 2022  39991.665734  40910.263636  38884.292308  39872.323776  3229.030693
#
#             trades
# year
# 2013    489.028571
# 2014    102.535211
# 2015    122.101370
# 2016   1306.759563
# 2017  14161.161644
# 2018  19339.312329
# 2019  17539.893151
# 2020  22526.715847
# 2021  47278.846575
# 2022  29090.608392

# %% [markdown]
# <b>Yearly Average Close Price </b>

# %%
fig, axes = plt.subplots(2,2, figsize=(16,12))

axes[0,0].set_title("Average Close Price")
sns.barplot(ax=axes[0,0], data = btc_avg, x = btc_avg.index, y=btc_avg["close"], palette="cool_r")

axes[0,1].set_title("Average Volume")
sns.barplot(ax=axes[0,1], data = btc_avg, x = btc_avg.index, y=btc_avg["volume"],palette="cool_r")


axes[1,0].set_title("Average Trades",)
sns.barplot(ax=axes[1,0], data = btc_avg, x = btc_avg.index, y=btc_avg["trades"],palette="cool_r")


plt.tight_layout(pad=2)

# %%
#df_2013 = btc_df_viz[btc_df_viz["year"]==2013]
#df_2014 = btc_df_viz[btc_df_viz["year"]==2014]
#df_2015 = btc_df_viz[btc_df_viz["year"]==2015]
#df_2016 = btc_df_viz[btc_df_viz["year"]==2016]
#df_2017 = btc_df_viz[btc_df_viz["year"]==2017]
#df_2018 = btc_df_viz[btc_df_viz["year"]==2018]
#df_2019 = btc_df_viz[btc_df_viz["year"]==2019]
#df_2020 = btc_df_viz[btc_df_viz["year"]==2020]
#df_2021 = btc_df_viz[btc_df_viz["year"]==2021]
#df_2022 = btc_df_viz[btc_df_viz["year"]==2022]

# %% [markdown]
# #### Heatmap showing  correlation score

# %%
cor_df= btc_df_viz.corr()

# %%
sns.heatmap(cor_df, cmap="coolwarm")
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### DataFrame with Dropping some Features

# %%
btc_df_less_features = btc_df.drop(["year", "month", "day"], axis=1) # not important

# %%
btc_df_less_features = btc_df_less_features.drop(["open", "high", "low","trades", "volume"], axis=1) 

# in reality, we don't know this on the current day or tomorrow day we want to predict
# we only know yesterday'open, yesterday'high, yesterday's low, and yesterday's close

# %%
btc_df_less_features.head(3)
# Out:
#                  close  open_yesterday  high_yesterday  low_yesterday  \
# date
# 2013-11-27   994.95000       801.59886       900.00000      768.58034
# 2013-11-28  1000.32893       893.90000      1081.09181      890.00000
# 2013-11-29  1165.42500       994.95000      1088.41486      935.08060
#
#             close_yesterday  volume_yesterday  trades_yesterday  \
# date
# 2013-11-27        893.87025         13.846622             351.0
# 2013-11-28        994.95000         46.413145             782.0
# 2013-11-29       1000.32893         33.030364             443.0
#
#             open_1D_change  high_1D_change  low_1D_change  close_1D_change  \
# date
# 2013-11-27       -0.004225        0.099752       0.052850         0.115109
# 2013-11-28        0.115146        0.201213       0.157979         0.113081
# 2013-11-29        0.113044        0.006774       0.050652         0.005406
#
#             volume_1D_change  trades_1D_change  open_average_7D  \
# date
# 2013-11-27          0.275832          0.290441       727.991971
# 2013-11-28          2.351947          1.227920       772.591843
# 2013-11-29         -0.288340         -0.433504       829.013271
#
#             high_average_7D  low_average_7D  close_average_7D  \
# date
# 2013-11-27       804.052834      671.933386        770.428236
# 2013-11-28       867.501920      734.790529        828.019664
# 2013-11-29       920.132614      785.071979        875.200880
#
#             volume_average_7D  trades_average_7D  open_%change_7D  \
# date
# 2013-11-27          32.574112         296.428571         0.084394
# 2013-11-28          31.094427         358.142857         0.025183
# 2013-11-29          25.518049         364.142857         0.065775
#
#             high_%change_7D  low_%change_7D  close_%change_7D  \
# date
# 2013-11-27         0.030572        0.064017          0.025034
# 2013-11-28         0.024414        0.075126          0.064433
# 2013-11-29         0.082275        0.107730          0.079544
#
#             volume_%change_7D  trades_%change_7D  moving_average_9  \
# date
# 2013-11-27           0.056438           0.146473        742.279831
# 2013-11-28           0.047896           0.077178        775.052053
# 2013-11-29           0.378996           0.299667        820.919620
#
#             moving_average_20  moving_average_50
# date
# 2013-11-27         540.766110         319.194435
# 2013-11-28         576.032168         336.653435
# 2013-11-29         609.516222         354.187814

# %% [markdown]
# <b> Save dataframe for machine learning model </b>

# %%
btc_df_less_features.to_csv("data/btc_df_less_features.csv")

# %% [markdown]
# ## MACHINE LEARNING MODEL

# %% [markdown]
# * Split train-test data using date since it's a time series data
#
# * not using train-test-split from sklearn since it will mix up the data

# %%
btc_ml_all = pd.read_csv("data/btc_df_less_features.csv", index_col=0)

# %%
btc_ml_all.head(3)
# Out:
#                  close  open_yesterday  high_yesterday  low_yesterday  \
# date
# 2013-11-27   994.95000       801.59886       900.00000      768.58034
# 2013-11-28  1000.32893       893.90000      1081.09181      890.00000
# 2013-11-29  1165.42500       994.95000      1088.41486      935.08060
#
#             close_yesterday  volume_yesterday  trades_yesterday  \
# date
# 2013-11-27        893.87025         13.846622             351.0
# 2013-11-28        994.95000         46.413145             782.0
# 2013-11-29       1000.32893         33.030364             443.0
#
#             open_1D_change  high_1D_change  low_1D_change  close_1D_change  \
# date
# 2013-11-27       -0.004225        0.099752       0.052850         0.115109
# 2013-11-28        0.115146        0.201213       0.157979         0.113081
# 2013-11-29        0.113044        0.006774       0.050652         0.005406
#
#             volume_1D_change  trades_1D_change  open_average_7D  \
# date
# 2013-11-27          0.275832          0.290441       727.991971
# 2013-11-28          2.351947          1.227920       772.591843
# 2013-11-29         -0.288340         -0.433504       829.013271
#
#             high_average_7D  low_average_7D  close_average_7D  \
# date
# 2013-11-27       804.052834      671.933386        770.428236
# 2013-11-28       867.501920      734.790529        828.019664
# 2013-11-29       920.132614      785.071979        875.200880
#
#             volume_average_7D  trades_average_7D  open_%change_7D  \
# date
# 2013-11-27          32.574112         296.428571         0.084394
# 2013-11-28          31.094427         358.142857         0.025183
# 2013-11-29          25.518049         364.142857         0.065775
#
#             high_%change_7D  low_%change_7D  close_%change_7D  \
# date
# 2013-11-27         0.030572        0.064017          0.025034
# 2013-11-28         0.024414        0.075126          0.064433
# 2013-11-29         0.082275        0.107730          0.079544
#
#             volume_%change_7D  trades_%change_7D  moving_average_9  \
# date
# 2013-11-27           0.056438           0.146473        742.279831
# 2013-11-28           0.047896           0.077178        775.052053
# 2013-11-29           0.378996           0.299667        820.919620
#
#             moving_average_20  moving_average_50
# date
# 2013-11-27         540.766110         319.194435
# 2013-11-28         576.032168         336.653435
# 2013-11-29         609.516222         354.187814

# %%
btc_ml_all.tail(3)
# Out:
#               close  open_yesterday  high_yesterday  low_yesterday  \
# date
# 2022-05-22  30268.0         29161.6         29606.3        28927.3
# 2022-05-23  29070.0         29394.4         30500.0        29225.7
# 2022-05-24  29340.0         30264.4         30630.7        28829.5
#
#             close_yesterday  volume_yesterday  trades_yesterday  \
# date
# 2022-05-22          29403.5       1030.060249           13342.0
# 2022-05-23          30268.0       1862.492124           15723.0
# 2022-05-24          29070.0       3028.927811           22623.0
#
#             open_1D_change  high_1D_change  low_1D_change  close_1D_change  \
# date
# 2022-05-22       -0.037053       -0.036291       0.007916         0.008091
# 2022-05-23        0.007983        0.030186       0.010316         0.029401
# 2022-05-24        0.029597        0.004285      -0.013557        -0.039580
#
#             volume_1D_change  trades_1D_change  open_average_7D  \
# date
# 2022-05-22         -0.722920         -0.444708     29954.800000
# 2022-05-23          0.808139          0.178459     29860.900000
# 2022-05-24          0.626277          0.438848     29713.742857
#
#             high_average_7D  low_average_7D  close_average_7D  \
# date
# 2022-05-22     30701.542857    28968.757143      29863.900000
# 2022-05-23     30574.400000    28936.342857      29716.914286
# 2022-05-24     30479.571429    28903.414286      29608.900000
#
#             volume_average_7D  trades_average_7D  open_%change_7D  \
# date
# 2022-05-22        2963.127501       23631.571429         0.007304
# 2022-05-23        3003.501844       22435.714286         0.000583
# 2022-05-24        2907.180888       21537.142857        -0.002278
#
#             high_%change_7D  low_%change_7D  close_%change_7D  \
# date
# 2022-05-22        -0.000971        0.000219          0.000658
# 2022-05-23        -0.002917        0.001769         -0.002222
# 2022-05-24        -0.003920       -0.001014         -0.003958
#
#             volume_%change_7D  trades_%change_7D  moving_average_9  \
# date
# 2022-05-22           0.099217          -0.047602      29813.122222
# 2022-05-23           0.047226          -0.087159      29929.277778
# 2022-05-24           0.223454          -0.032349      29820.588889
#
#             moving_average_20  moving_average_50
# date
# 2022-05-22          32264.440          37598.628
# 2022-05-23          31852.845          37287.416
# 2022-05-24          31419.950          36940.348

# %% [markdown]
# #### Drop the last row because we want to predict the price of the current day

# %%
last_row = btc_ml_all[-1:]
last_row
# Out:
#               close  open_yesterday  high_yesterday  low_yesterday  \
# date
# 2022-05-24  29340.0         30264.4         30630.7        28829.5
#
#             close_yesterday  volume_yesterday  trades_yesterday  \
# date
# 2022-05-24          29070.0       3028.927811           22623.0
#
#             open_1D_change  high_1D_change  low_1D_change  close_1D_change  \
# date
# 2022-05-24        0.029597        0.004285      -0.013557         -0.03958
#
#             volume_1D_change  trades_1D_change  open_average_7D  \
# date
# 2022-05-24          0.626277          0.438848     29713.742857
#
#             high_average_7D  low_average_7D  close_average_7D  \
# date
# 2022-05-24     30479.571429    28903.414286           29608.9
#
#             volume_average_7D  trades_average_7D  open_%change_7D  \
# date
# 2022-05-24        2907.180888       21537.142857        -0.002278
#
#             high_%change_7D  low_%change_7D  close_%change_7D  \
# date
# 2022-05-24         -0.00392       -0.001014         -0.003958
#
#             volume_%change_7D  trades_%change_7D  moving_average_9  \
# date
# 2022-05-24           0.223454          -0.032349      29820.588889
#
#             moving_average_20  moving_average_50
# date
# 2022-05-24           31419.95          36940.348

# %%
btc_ml = btc_ml_all[:-1]
btc_ml.head(2)
# Out:
#                  close  open_yesterday  high_yesterday  low_yesterday  \
# date
# 2013-11-27   994.95000       801.59886       900.00000      768.58034
# 2013-11-28  1000.32893       893.90000      1081.09181      890.00000
#
#             close_yesterday  volume_yesterday  trades_yesterday  \
# date
# 2013-11-27        893.87025         13.846622             351.0
# 2013-11-28        994.95000         46.413145             782.0
#
#             open_1D_change  high_1D_change  low_1D_change  close_1D_change  \
# date
# 2013-11-27       -0.004225        0.099752       0.052850         0.115109
# 2013-11-28        0.115146        0.201213       0.157979         0.113081
#
#             volume_1D_change  trades_1D_change  open_average_7D  \
# date
# 2013-11-27          0.275832          0.290441       727.991971
# 2013-11-28          2.351947          1.227920       772.591843
#
#             high_average_7D  low_average_7D  close_average_7D  \
# date
# 2013-11-27       804.052834      671.933386        770.428236
# 2013-11-28       867.501920      734.790529        828.019664
#
#             volume_average_7D  trades_average_7D  open_%change_7D  \
# date
# 2013-11-27          32.574112         296.428571         0.084394
# 2013-11-28          31.094427         358.142857         0.025183
#
#             high_%change_7D  low_%change_7D  close_%change_7D  \
# date
# 2013-11-27         0.030572        0.064017          0.025034
# 2013-11-28         0.024414        0.075126          0.064433
#
#             volume_%change_7D  trades_%change_7D  moving_average_9  \
# date
# 2013-11-27           0.056438           0.146473        742.279831
# 2013-11-28           0.047896           0.077178        775.052053
#
#             moving_average_20  moving_average_50
# date
# 2013-11-27         540.766110         319.194435
# 2013-11-28         576.032168         336.653435

# %%
btc_ml.tail(2)
# Out:
#               close  open_yesterday  high_yesterday  low_yesterday  \
# date
# 2022-05-22  30268.0         29161.6         29606.3        28927.3
# 2022-05-23  29070.0         29394.4         30500.0        29225.7
#
#             close_yesterday  volume_yesterday  trades_yesterday  \
# date
# 2022-05-22          29403.5       1030.060249           13342.0
# 2022-05-23          30268.0       1862.492124           15723.0
#
#             open_1D_change  high_1D_change  low_1D_change  close_1D_change  \
# date
# 2022-05-22       -0.037053       -0.036291       0.007916         0.008091
# 2022-05-23        0.007983        0.030186       0.010316         0.029401
#
#             volume_1D_change  trades_1D_change  open_average_7D  \
# date
# 2022-05-22         -0.722920         -0.444708          29954.8
# 2022-05-23          0.808139          0.178459          29860.9
#
#             high_average_7D  low_average_7D  close_average_7D  \
# date
# 2022-05-22     30701.542857    28968.757143      29863.900000
# 2022-05-23     30574.400000    28936.342857      29716.914286
#
#             volume_average_7D  trades_average_7D  open_%change_7D  \
# date
# 2022-05-22        2963.127501       23631.571429         0.007304
# 2022-05-23        3003.501844       22435.714286         0.000583
#
#             high_%change_7D  low_%change_7D  close_%change_7D  \
# date
# 2022-05-22        -0.000971        0.000219          0.000658
# 2022-05-23        -0.002917        0.001769         -0.002222
#
#             volume_%change_7D  trades_%change_7D  moving_average_9  \
# date
# 2022-05-22           0.099217          -0.047602      29813.122222
# 2022-05-23           0.047226          -0.087159      29929.277778
#
#             moving_average_20  moving_average_50
# date
# 2022-05-22          32264.440          37598.628
# 2022-05-23          31852.845          37287.416

# %% [markdown]
# #### Split train-test 85:15
# * Can't use train-test split because it will shuffle the data/date index

# %%
len(btc_ml)
# Out:
# 3090

# %%
train_size = (85*(len(btc_ml)))//100
train_size
# Out:
# 2626

# %% [markdown]
# **Train Set**

# %%
train_set = btc_ml.iloc[0:train_size]
train_set.tail(3)
# Out:
#               close  open_yesterday  high_yesterday  low_yesterday  \
# date
# 2021-02-11  47962.8         46504.5         47340.0        43734.8
# 2021-02-12  47470.4         44839.5         48703.6        44046.2
# 2021-02-13  47199.9         47979.9         48925.0        46263.0
#
#             close_yesterday  volume_yesterday  trades_yesterday  \
# date
# 2021-02-11          44847.5       6451.558931           70018.0
# 2021-02-12          47962.8       7962.974924           75748.0
# 2021-02-13          47470.4       5332.296303           61266.0
#
#             open_1D_change  high_1D_change  low_1D_change  close_1D_change  \
# date
# 2021-02-11        0.001697       -0.018290      -0.029194        -0.035596
# 2021-02-12       -0.035803        0.028804       0.007120         0.069464
# 2021-02-13        0.070036        0.004546       0.050329        -0.010266
#
#             volume_1D_change  trades_1D_change  open_average_7D  \
# date
# 2021-02-11         -0.389878         -0.276517     40573.971429
# 2021-02-12          0.234271          0.081836     41597.328571
# 2021-02-13         -0.330364         -0.191187     43169.342857
#
#             high_average_7D  low_average_7D  close_average_7D  \
# date
# 2021-02-11     42864.957143    39325.228571      41597.671429
# 2021-02-12     44289.028571    40445.828571      43166.785714
# 2021-02-13     45801.171429    41828.700000      44477.314286
#
#             volume_average_7D  trades_average_7D  open_%change_7D  \
# date
# 2021-02-11        8135.577671       71329.285714         0.049526
# 2021-02-12        8248.500798       73491.142857         0.041393
# 2021-02-13        8323.179870       76353.714286         0.027522
#
#             high_%change_7D  low_%change_7D  close_%change_7D  \
# date
# 2021-02-11         0.044440        0.045087          0.041379
# 2021-02-12         0.035176        0.032666          0.027558
# 2021-02-13         0.035275        0.030425          0.040106
#
#             volume_%change_7D  trades_%change_7D  moving_average_9  \
# date
# 2021-02-11           0.231112           0.200813      40483.844444
# 2021-02-12           0.171454           0.149587      41868.600000
# 2021-02-13           0.201697           0.134442      42957.433333
#
#             moving_average_20  moving_average_50
# date
# 2021-02-11          36279.560          34238.732
# 2021-02-12          37027.700          34733.454
# 2021-02-13          37796.195          35208.490

# %% [markdown]
# **Test Set**

# %%
test_set = btc_ml[train_size:]
test_set.head(3)
# Out:
#               close  open_yesterday  high_yesterday  low_yesterday  \
# date
# 2021-02-14  48649.7         47438.2         48224.1        46285.0
# 2021-02-15  47937.1         47199.9         49700.0        47038.7
# 2021-02-16  49218.7         48655.4         49043.3        45710.5
#
#             close_yesterday  volume_yesterday  trades_yesterday  \
# date
# 2021-02-14          47199.9       2631.808897           39366.0
# 2021-02-15          48649.7       3553.112138           50594.0
# 2021-02-16          47937.1       5337.999243           61326.0
#
#             open_1D_change  high_1D_change  low_1D_change  close_1D_change  \
# date
# 2021-02-14       -0.011290       -0.014326       0.000476        -0.005698
# 2021-02-15       -0.005023        0.030605       0.016284         0.030716
# 2021-02-16        0.030837       -0.013213      -0.028236        -0.014648
#
#             volume_1D_change  trades_1D_change  open_average_7D  \
# date
# 2021-02-14         -0.506440         -0.357458     44473.128571
# 2021-02-15          0.350065          0.285221     45607.828571
# 2021-02-16          0.502345          0.212120     47006.157143
#
#             high_average_7D  low_average_7D  close_average_7D  \
# date
# 2021-02-14     46835.185714    42980.642857      45612.014286
# 2021-02-15     48263.128571    44356.100000      47008.414286
# 2021-02-16     48594.000000    45446.885714      47224.314286
#
#             volume_average_7D  trades_average_7D  open_%change_7D  \
# date
# 2021-02-14        7395.328670       71958.857143         0.040182
# 2021-02-15        7169.267541       71886.571429         0.033408
# 2021-02-16        5977.709736       65013.857143         0.029165
#
#             high_%change_7D  low_%change_7D  close_%change_7D  \
# date
# 2021-02-14         0.037382        0.036112          0.033548
# 2021-02-15         0.025476        0.029781          0.029152
# 2021-02-16         0.034315        0.035138          0.034931
#
#             volume_%change_7D  trades_%change_7D  moving_average_9  \
# date
# 2021-02-14           0.201566           0.152821      44093.088889
# 2021-02-15           0.000984           0.001608      45243.422222
# 2021-02-16           0.113466           0.081119      46207.877778
#
#             moving_average_20  moving_average_50
# date
# 2021-02-14          38541.590          35658.516
# 2021-02-15          39360.355          36102.686
# 2021-02-16          40132.160          36536.400

# %% [markdown]
# **X_train, y_train, X_test, y_test**

# %% [markdown]
# <b>X_train</b>

# %%
X_train_new = train_set.drop(["close"], axis=1)
X_train_new.head(3)
# Out:
#             open_yesterday  high_yesterday  low_yesterday  close_yesterday  \
# date
# 2013-11-27       801.59886       900.00000      768.58034        893.87025
# 2013-11-28       893.90000      1081.09181      890.00000        994.95000
# 2013-11-29       994.95000      1088.41486      935.08060       1000.32893
#
#             volume_yesterday  trades_yesterday  open_1D_change  \
# date
# 2013-11-27         13.846622             351.0       -0.004225
# 2013-11-28         46.413145             782.0        0.115146
# 2013-11-29         33.030364             443.0        0.113044
#
#             high_1D_change  low_1D_change  close_1D_change  volume_1D_change  \
# date
# 2013-11-27        0.099752       0.052850         0.115109          0.275832
# 2013-11-28        0.201213       0.157979         0.113081          2.351947
# 2013-11-29        0.006774       0.050652         0.005406         -0.288340
#
#             trades_1D_change  open_average_7D  high_average_7D  \
# date
# 2013-11-27          0.290441       727.991971       804.052834
# 2013-11-28          1.227920       772.591843       867.501920
# 2013-11-29         -0.433504       829.013271       920.132614
#
#             low_average_7D  close_average_7D  volume_average_7D  \
# date
# 2013-11-27      671.933386        770.428236          32.574112
# 2013-11-28      734.790529        828.019664          31.094427
# 2013-11-29      785.071979        875.200880          25.518049
#
#             trades_average_7D  open_%change_7D  high_%change_7D  \
# date
# 2013-11-27         296.428571         0.084394         0.030572
# 2013-11-28         358.142857         0.025183         0.024414
# 2013-11-29         364.142857         0.065775         0.082275
#
#             low_%change_7D  close_%change_7D  volume_%change_7D  \
# date
# 2013-11-27        0.064017          0.025034           0.056438
# 2013-11-28        0.075126          0.064433           0.047896
# 2013-11-29        0.107730          0.079544           0.378996
#
#             trades_%change_7D  moving_average_9  moving_average_20  \
# date
# 2013-11-27           0.146473        742.279831         540.766110
# 2013-11-28           0.077178        775.052053         576.032168
# 2013-11-29           0.299667        820.919620         609.516222
#
#             moving_average_50
# date
# 2013-11-27         319.194435
# 2013-11-28         336.653435
# 2013-11-29         354.187814

# %%
X_train = X_train_new.values
X_train.shape
# Out:
# (2626, 27)

# %% [markdown]
# <b>X_test</b>

# %%
X_test_new = test_set.drop(["close"], axis=1)

# %%
X_test_new.head(3)
# Out:
#             open_yesterday  high_yesterday  low_yesterday  close_yesterday  \
# date
# 2021-02-14         47438.2         48224.1        46285.0          47199.9
# 2021-02-15         47199.9         49700.0        47038.7          48649.7
# 2021-02-16         48655.4         49043.3        45710.5          47937.1
#
#             volume_yesterday  trades_yesterday  open_1D_change  \
# date
# 2021-02-14       2631.808897           39366.0       -0.011290
# 2021-02-15       3553.112138           50594.0       -0.005023
# 2021-02-16       5337.999243           61326.0        0.030837
#
#             high_1D_change  low_1D_change  close_1D_change  volume_1D_change  \
# date
# 2021-02-14       -0.014326       0.000476        -0.005698         -0.506440
# 2021-02-15        0.030605       0.016284         0.030716          0.350065
# 2021-02-16       -0.013213      -0.028236        -0.014648          0.502345
#
#             trades_1D_change  open_average_7D  high_average_7D  \
# date
# 2021-02-14         -0.357458     44473.128571     46835.185714
# 2021-02-15          0.285221     45607.828571     48263.128571
# 2021-02-16          0.212120     47006.157143     48594.000000
#
#             low_average_7D  close_average_7D  volume_average_7D  \
# date
# 2021-02-14    42980.642857      45612.014286        7395.328670
# 2021-02-15    44356.100000      47008.414286        7169.267541
# 2021-02-16    45446.885714      47224.314286        5977.709736
#
#             trades_average_7D  open_%change_7D  high_%change_7D  \
# date
# 2021-02-14       71958.857143         0.040182         0.037382
# 2021-02-15       71886.571429         0.033408         0.025476
# 2021-02-16       65013.857143         0.029165         0.034315
#
#             low_%change_7D  close_%change_7D  volume_%change_7D  \
# date
# 2021-02-14        0.036112          0.033548           0.201566
# 2021-02-15        0.029781          0.029152           0.000984
# 2021-02-16        0.035138          0.034931           0.113466
#
#             trades_%change_7D  moving_average_9  moving_average_20  \
# date
# 2021-02-14           0.152821      44093.088889          38541.590
# 2021-02-15           0.001608      45243.422222          39360.355
# 2021-02-16           0.081119      46207.877778          40132.160
#
#             moving_average_50
# date
# 2021-02-14          35658.516
# 2021-02-15          36102.686
# 2021-02-16          36536.400

# %%
X_test = X_test_new.values
X_test.shape
# Out:
# (464, 27)

# %% [markdown]
# <b> y_train </b>

# %%
y_train_new = train_set["close"]

# %%
y_train = y_train_new.values
y_train.shape
# Out:
# (2626,)

# %% [markdown]
# <b>y_test</b>

# %%
y_test_new = test_set["close"]
y_test = y_test_new.values
y_test.shape
# Out:
# (464,)

# %% [markdown]
# ## Support Vector Machine

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.metrics  import mean_squared_error, r2_score
from sklearn.svm import SVR

# %% [markdown]
# ### Scale featues

# %%
scaler = StandardScaler()

# %%
X_scaled_train = scaler.fit_transform(X_train)

# %%
X_scaled_test = scaler.transform(X_test) 
# not using fit to avoid data leakage

# %% [markdown]
# ### Base Model1:  Not Scale and Not Adjust Parameters

# %%
svr_base1 = SVR()

# %%
svr_base1.fit(X_train , y_train)
# Out:
# SVR()

# %%
pred_base1 = svr_base1.predict(X_test)

# %%
print(np.sqrt(mean_squared_error(y_test, pred_base1)))
# Out:
# 44436.328803863355

# %%
print(r2_score(y_test, pred_base1))
# Out:
# -22.479785759485132

# %% [markdown]
# ### Base Model2: Scale but Not Adjust Parameters

# %%
svr_base2 = SVR()

# %%
svr_base2.fit(X_scaled_train, y_train)
# Out:
# SVR()

# %%
pred_base2 = svr_base2.predict(X_scaled_test)

# %%
print(np.sqrt(mean_squared_error(y_test, pred_base2)))
# Out:
# 44312.63673133776

# %%
print(r2_score(y_test, pred_base2))
# Out:
# -22.349251968034416

# %% [markdown]
# ### Model 3: Adjusted Model: Scale + Adjust Parameters

# %%
param_grid = {'kernel': ['linear'], 'C': [100,300, 500], 'epsilon': [0.00001, 0.0001, 0.001]}

# %%
svr = SVR()

# %%
# %%time
grid_search = GridSearchCV(svr, param_grid, cv=5, scoring='r2')
# Out:
# CPU times: user 80 µs, sys: 6 µs, total: 86 µs
# Wall time: 103 µs

# %%
# %%time
grid_search.fit(X_scaled_train, y_train)
# Out:
# CPU times: user 1min 18s, sys: 184 ms, total: 1min 19s
# Wall time: 1min 19s
# GridSearchCV(cv=5, estimator=SVR(),
#              param_grid={'C': [100, 300, 500],
#                          'epsilon': [1e-05, 0.0001, 0.001],
#                          'kernel': ['linear']},
#              scoring='r2')

# %%
# %%time
print(grid_search.best_params_)
# Out:
# {'C': 300, 'epsilon': 0.0001, 'kernel': 'linear'}
# CPU times: user 25 µs, sys: 3 µs, total: 28 µs
# Wall time: 28.8 µs

# %%
svr_best = grid_search.best_estimator_

# %%
pred_svr_adjusted = svr_best.predict(X_scaled_test)

# %%
print(np.sqrt(mean_squared_error(y_test, pred_svr_adjusted)))
# Out:
# 1795.0982090107339

# %%
print(r2_score(y_test, pred_svr_adjusted))
# Out:
# 0.9616827604728481

# %%
len(y_test)
# Out:
# 464

# %%
len(pred_svr_adjusted)
# Out:
# 464

# %%
test_set["close"]
# Out:
# date
# 2021-02-14    48649.7
# 2021-02-15    47937.1
# 2021-02-16    49218.7
# 2021-02-17    52130.0
# 2021-02-18    51600.9
#                ...
# 2022-05-19    30280.7
# 2022-05-20    29167.5
# 2022-05-21    29403.5
# 2022-05-22    30268.0
# 2022-05-23    29070.0
# Name: close, Length: 464, dtype: float64

# %%
df_compare = pd.DataFrame(columns=["actual_price", "predicted_price"])

# %%
df_compare
# Out:
# Empty DataFrame
# Columns: [actual_price, predicted_price]
# Index: []

# %%
df_compare["actual_price"] = test_set["close"]

# %%
df_compare["predicted_price"] = pred_svr_adjusted

# %%
df_compare["difference"] =  df_compare["actual_price"] - df_compare["predicted_price"]

# %%
df_compare.head(10)
# Out:
#             actual_price  predicted_price   difference
# date
# 2021-02-14       48649.7     47524.588092  1125.111908
# 2021-02-15       47937.1     48872.130862  -935.030862
# 2021-02-16       49218.7     47963.774791  1254.925209
# 2021-02-17       52130.0     49317.574815  2812.425185
# 2021-02-18       51600.9     51827.318767  -226.418767
# 2021-02-19       55926.9     51890.374967  4036.525033
# 2021-02-20       55938.7     55030.816078   907.883922
# 2021-02-21       57478.3     56063.121127  1415.178873
# 2021-02-22       54154.8     57443.302026 -3288.502026
# 2021-02-23       48899.8     52982.219817 -4082.419817

# %%
df_compare.tail(15)
# Out:
#             actual_price  predicted_price   difference
# date
# 2022-05-09       30075.5     34205.389143 -4129.889143
# 2022-05-10       30999.9     30966.943782    32.956218
# 2022-05-11       28994.1     31071.114173 -2077.014173
# 2022-05-12       28943.4     29346.037822  -402.637822
# 2022-05-13       29222.6     28267.884145   954.715855
# 2022-05-14       30048.2     29388.331835   659.868165
# 2022-05-15       31296.9     29604.138374  1692.761626
# 2022-05-16       29826.1     30700.635143  -874.535143
# 2022-05-17       30408.3     29797.292957   611.007043
# 2022-05-18       28664.3     30072.820018 -1408.520018
# 2022-05-19       30280.7     28932.393909  1348.306091
# 2022-05-20       29167.5     29802.225770  -634.725770
# 2022-05-21       29403.5     29249.974568   153.525432
# 2022-05-22       30268.0     29198.954989  1069.045011
# 2022-05-23       29070.0     29933.005300  -863.005300

# %%
plt.plot(df_compare.index , df_compare.actual_price, label="Actual Price")
plt.plot(df_compare.index , df_compare.predicted_price, label="Predicted Price")
plt.legend()
plt.show()

# %% [markdown]
# # LIVE PREDICTION

# %% [markdown]
# * This section is trying to test the model performance on live prediction
# * The model will predict the price the next day
# * Therefore, there will be only one row of test set
# * y_test will be known at the end of trading day

# %% [markdown]
# #### 1. Dataset is from 2013 to Current day

# %%
btc_ml.head(2)
# Out:
#                  close  open_yesterday  high_yesterday  low_yesterday  \
# date
# 2013-11-27   994.95000       801.59886       900.00000      768.58034
# 2013-11-28  1000.32893       893.90000      1081.09181      890.00000
#
#             close_yesterday  volume_yesterday  trades_yesterday  \
# date
# 2013-11-27        893.87025         13.846622             351.0
# 2013-11-28        994.95000         46.413145             782.0
#
#             open_1D_change  high_1D_change  low_1D_change  close_1D_change  \
# date
# 2013-11-27       -0.004225        0.099752       0.052850         0.115109
# 2013-11-28        0.115146        0.201213       0.157979         0.113081
#
#             volume_1D_change  trades_1D_change  open_average_7D  \
# date
# 2013-11-27          0.275832          0.290441       727.991971
# 2013-11-28          2.351947          1.227920       772.591843
#
#             high_average_7D  low_average_7D  close_average_7D  \
# date
# 2013-11-27       804.052834      671.933386        770.428236
# 2013-11-28       867.501920      734.790529        828.019664
#
#             volume_average_7D  trades_average_7D  open_%change_7D  \
# date
# 2013-11-27          32.574112         296.428571         0.084394
# 2013-11-28          31.094427         358.142857         0.025183
#
#             high_%change_7D  low_%change_7D  close_%change_7D  \
# date
# 2013-11-27         0.030572        0.064017          0.025034
# 2013-11-28         0.024414        0.075126          0.064433
#
#             volume_%change_7D  trades_%change_7D  moving_average_9  \
# date
# 2013-11-27           0.056438           0.146473        742.279831
# 2013-11-28           0.047896           0.077178        775.052053
#
#             moving_average_20  moving_average_50
# date
# 2013-11-27         540.766110         319.194435
# 2013-11-28         576.032168         336.653435

# %%
btc_ml.tail(2)
# Out:
#               close  open_yesterday  high_yesterday  low_yesterday  \
# date
# 2022-05-22  30268.0         29161.6         29606.3        28927.3
# 2022-05-23  29070.0         29394.4         30500.0        29225.7
#
#             close_yesterday  volume_yesterday  trades_yesterday  \
# date
# 2022-05-22          29403.5       1030.060249           13342.0
# 2022-05-23          30268.0       1862.492124           15723.0
#
#             open_1D_change  high_1D_change  low_1D_change  close_1D_change  \
# date
# 2022-05-22       -0.037053       -0.036291       0.007916         0.008091
# 2022-05-23        0.007983        0.030186       0.010316         0.029401
#
#             volume_1D_change  trades_1D_change  open_average_7D  \
# date
# 2022-05-22         -0.722920         -0.444708          29954.8
# 2022-05-23          0.808139          0.178459          29860.9
#
#             high_average_7D  low_average_7D  close_average_7D  \
# date
# 2022-05-22     30701.542857    28968.757143      29863.900000
# 2022-05-23     30574.400000    28936.342857      29716.914286
#
#             volume_average_7D  trades_average_7D  open_%change_7D  \
# date
# 2022-05-22        2963.127501       23631.571429         0.007304
# 2022-05-23        3003.501844       22435.714286         0.000583
#
#             high_%change_7D  low_%change_7D  close_%change_7D  \
# date
# 2022-05-22        -0.000971        0.000219          0.000658
# 2022-05-23        -0.002917        0.001769         -0.002222
#
#             volume_%change_7D  trades_%change_7D  moving_average_9  \
# date
# 2022-05-22           0.099217          -0.047602      29813.122222
# 2022-05-23           0.047226          -0.087159      29929.277778
#
#             moving_average_20  moving_average_50
# date
# 2022-05-22          32264.440          37598.628
# 2022-05-23          31852.845          37287.416

# %% [markdown]
# #### 2. Training Set is from 2013 to yesterday price

# %% [markdown]
# <b> X_train</b>

# %%
X_train_new2 = btc_ml.drop(["close"], axis=1)
X_train_new2.head(2)
# Out:
#             open_yesterday  high_yesterday  low_yesterday  close_yesterday  \
# date
# 2013-11-27       801.59886       900.00000      768.58034        893.87025
# 2013-11-28       893.90000      1081.09181      890.00000        994.95000
#
#             volume_yesterday  trades_yesterday  open_1D_change  \
# date
# 2013-11-27         13.846622             351.0       -0.004225
# 2013-11-28         46.413145             782.0        0.115146
#
#             high_1D_change  low_1D_change  close_1D_change  volume_1D_change  \
# date
# 2013-11-27        0.099752       0.052850         0.115109          0.275832
# 2013-11-28        0.201213       0.157979         0.113081          2.351947
#
#             trades_1D_change  open_average_7D  high_average_7D  \
# date
# 2013-11-27          0.290441       727.991971       804.052834
# 2013-11-28          1.227920       772.591843       867.501920
#
#             low_average_7D  close_average_7D  volume_average_7D  \
# date
# 2013-11-27      671.933386        770.428236          32.574112
# 2013-11-28      734.790529        828.019664          31.094427
#
#             trades_average_7D  open_%change_7D  high_%change_7D  \
# date
# 2013-11-27         296.428571         0.084394         0.030572
# 2013-11-28         358.142857         0.025183         0.024414
#
#             low_%change_7D  close_%change_7D  volume_%change_7D  \
# date
# 2013-11-27        0.064017          0.025034           0.056438
# 2013-11-28        0.075126          0.064433           0.047896
#
#             trades_%change_7D  moving_average_9  moving_average_20  \
# date
# 2013-11-27           0.146473        742.279831         540.766110
# 2013-11-28           0.077178        775.052053         576.032168
#
#             moving_average_50
# date
# 2013-11-27         319.194435
# 2013-11-28         336.653435

# %%
X_train_new2.tail(2)
# Out:
#             open_yesterday  high_yesterday  low_yesterday  close_yesterday  \
# date
# 2022-05-22         29161.6         29606.3        28927.3          29403.5
# 2022-05-23         29394.4         30500.0        29225.7          30268.0
#
#             volume_yesterday  trades_yesterday  open_1D_change  \
# date
# 2022-05-22       1030.060249           13342.0       -0.037053
# 2022-05-23       1862.492124           15723.0        0.007983
#
#             high_1D_change  low_1D_change  close_1D_change  volume_1D_change  \
# date
# 2022-05-22       -0.036291       0.007916         0.008091         -0.722920
# 2022-05-23        0.030186       0.010316         0.029401          0.808139
#
#             trades_1D_change  open_average_7D  high_average_7D  \
# date
# 2022-05-22         -0.444708          29954.8     30701.542857
# 2022-05-23          0.178459          29860.9     30574.400000
#
#             low_average_7D  close_average_7D  volume_average_7D  \
# date
# 2022-05-22    28968.757143      29863.900000        2963.127501
# 2022-05-23    28936.342857      29716.914286        3003.501844
#
#             trades_average_7D  open_%change_7D  high_%change_7D  \
# date
# 2022-05-22       23631.571429         0.007304        -0.000971
# 2022-05-23       22435.714286         0.000583        -0.002917
#
#             low_%change_7D  close_%change_7D  volume_%change_7D  \
# date
# 2022-05-22        0.000219          0.000658           0.099217
# 2022-05-23        0.001769         -0.002222           0.047226
#
#             trades_%change_7D  moving_average_9  moving_average_20  \
# date
# 2022-05-22          -0.047602      29813.122222          32264.440
# 2022-05-23          -0.087159      29929.277778          31852.845
#
#             moving_average_50
# date
# 2022-05-22          37598.628
# 2022-05-23          37287.416

# %%
X_train2 = X_train_new2.values
X_train2.shape
# Out:
# (3090, 27)

# %% [markdown]
# <b> y_train </b>

# %%
y_train_new = btc_ml["close"]
y_train2 = y_train_new.values
y_train2.shape
# Out:
# (3090,)

# %% [markdown]
# #### 3. Test set is current trading day , today ( the last row)

# %%
X_test2 = last_row.drop(["close"], axis=1)
X_test2
# Out:
#             open_yesterday  high_yesterday  low_yesterday  close_yesterday  \
# date
# 2022-05-24         30264.4         30630.7        28829.5          29070.0
#
#             volume_yesterday  trades_yesterday  open_1D_change  \
# date
# 2022-05-24       3028.927811           22623.0        0.029597
#
#             high_1D_change  low_1D_change  close_1D_change  volume_1D_change  \
# date
# 2022-05-24        0.004285      -0.013557         -0.03958          0.626277
#
#             trades_1D_change  open_average_7D  high_average_7D  \
# date
# 2022-05-24          0.438848     29713.742857     30479.571429
#
#             low_average_7D  close_average_7D  volume_average_7D  \
# date
# 2022-05-24    28903.414286           29608.9        2907.180888
#
#             trades_average_7D  open_%change_7D  high_%change_7D  \
# date
# 2022-05-24       21537.142857        -0.002278         -0.00392
#
#             low_%change_7D  close_%change_7D  volume_%change_7D  \
# date
# 2022-05-24       -0.001014         -0.003958           0.223454
#
#             trades_%change_7D  moving_average_9  moving_average_20  \
# date
# 2022-05-24          -0.032349      29820.588889           31419.95
#
#             moving_average_50
# date
# 2022-05-24          36940.348

# %% [markdown]
# <b> y_actual </b>

# %% [markdown]
# #### 4. Model Prediciton

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.metrics  import mean_squared_error, r2_score
from sklearn.svm import SVR

# %% [markdown]
# ### Scale featues

# %%
scaler = StandardScaler()

# %%
X_scaled_train2 = scaler.fit_transform(X_train2)

# %%
X_scaled_test2 = scaler.transform(X_test2) # not using fit to avoid data leakage
# Out:
# /Users/daranee/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:443: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(

# %%
param_grid2 = {'kernel': ['linear'], 'C': [100,300, 500], 'epsilon': [0.00001, 0.0001, 0.001]}

# %%
svr2 = SVR()

# %%
# %%time
grid_search2 = GridSearchCV(svr2, param_grid2, cv=5, scoring='r2')
# Out:
# CPU times: user 79 µs, sys: 57 µs, total: 136 µs
# Wall time: 148 µs

# %%
# %%time
grid_search2.fit(X_scaled_train2, y_train2)
# Out:
# CPU times: user 1min 16s, sys: 188 ms, total: 1min 16s
# Wall time: 1min 16s
# GridSearchCV(cv=5, estimator=SVR(),
#              param_grid={'C': [100, 300, 500],
#                          'epsilon': [1e-05, 0.0001, 0.001],
#                          'kernel': ['linear']},
#              scoring='r2')

# %%
# %%time
print(grid_search2.best_params_)
# Out:
# {'C': 500, 'epsilon': 1e-05, 'kernel': 'linear'}
# CPU times: user 24 µs, sys: 2 µs, total: 26 µs
# Wall time: 27.9 µs

# %%
svr_best2 = grid_search2.best_estimator_

# %%
pred_svr_adjusted2 = svr_best2.predict(X_scaled_test2)

# %%
pred_svr_adjusted2
# Out:
# array([29384.95501957])

# %% [markdown]
# #### Create a new dataframe

# %%
new_cols = ["date","predict", "actual"]

# %%
df_actual = pd.DataFrame(columns=new_cols)
df_actual
# Out:
# Empty DataFrame
# Columns: [date, predict, actual]
# Index: []

# %%
df_actual["date"]= last_row.index
df_actual
# Out:
#          date predict actual
# 0  2022-05-24     NaN    NaN

# %%
df_actual["predict"] = pred_svr_adjusted2
df_actual
# Out:
#          date      predict actual
# 0  2022-05-24  29384.95502    NaN

# %%
df_actual[0:1]["date"].values
# Out:
# array(['2022-04-19'], dtype=object)

# %%
x = np.asscalar(df_actual[0:1]["date"].values)
x
# Out:
# /var/folders/rk/_5r1csw96vn4r_l01g_prd_h0000gn/T/ipykernel_12914/3410238289.py:1: DeprecationWarning: np.asscalar(a) is deprecated since NumPy v1.16, use a.item() instead
#   x = np.asscalar(df_actual[0:1]["date"].values)
# '2022-04-17'

# %% [markdown]
# #### Call Kraken OHLCVVT API again at the end of day
# #### Run at the end of day

# %% [markdown]
# resp2 = requests.get('https://api.kraken.com/0/public/OHLC?pair=XBTUSD&interval=1440&since=unix_now').json()

# %% [markdown]
# xbt_new_df = pd.DataFrame(resp2["result"]['XXBTZUSD'])
# xbt_new_df.columns = kraken_ohlc_cols
# xbt_new_df["date"] = pd.to_datetime(xbt_new_df["date"],unit='s')
# xbt_new_df.tail(10)

# %% [markdown]
# filter = xbt_new_df["date"]==x
# filter

# %% [markdown]
# xbt_new_df[filter]

# %% [markdown]
# xbt_new_df[filter]["close"]

# %% [markdown]
# df_actual["actual"] = xbt_new_df[filter]["close"].values

# %% [markdown]
# df_actual

# %% [markdown]
# df_compare2 = pd.DataFrame(columns=new_cols )

# %% [markdown]
# df_compare2

# %% [markdown]
# df_compare2.append(df_actual)

# %% [markdown]
# print(np.sqrt(mean_squared_error(y_test2, pred_svr_adjusted2)))

# %% [markdown]
# print(r2_score(y_test2, pred_svr_adjusted2))

# %% [markdown]
# plt.plot(pred_svr_adjusted, label="SVR Predition Price")
# plt.plot(y_test, label="Actual Close Price")
# plt.legend()
